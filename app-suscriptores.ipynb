# %% [markdown]
# ## Problema: Crecimiento de Suscriptores en una Plataforma Digital
#
# **Instrucción:** completa esta plantilla con tu diseño y desarrollo. Evita incluir soluciones generadas automáticamente.

# %%
# @title Ingrese datos
nombre_estudiante = "Daniel Felipe Buitrago González" # @param {"type":"string"}
carnet = 1000116039 # @param {"type":"integer"}

# %% [markdown]
# ## 1) Descripción del problema **[1 pts]**
# Una plataforma de streaming está analizando el crecimiento de nuevos suscriptores.
# Se ha observado que el número de nuevos suscriptores en el mes n sigue el siguiente
# comportamiento:
# • En el mes 0 se registraron 0 nuevos usuarios.
# • En el mes 1 se registró 1 nuevo usuario.
# • A partir del mes 2, el número de nuevos usuarios es igual a la suma de los nuevos usuarios de
# los dos meses anteriores, debido al efecto combinado de referidos del mes anterior y
# recomendaciones acumuladas del mes previo.
#
# Relación de recurrencia:
# T(n) = 0 si n = 0
# T(n) = 1 si n = 1
# T(n) = T(n-1) + T(n-2) si n ≥ 2
#
# Determinar con memoización cuántos nuevos suscriptores habrá en el mes n.

# %% [markdown]
# ## 2) Requerimientos **[2 pts]**
#
# Lista requerimientos **funcionales** y **no funcionales**.
#
# Requerimientos funcionales:
#
# -Permitir registrar al usuario
#
# -Almacenar en la memoria los casos base (n=0 y n=1)
#
# -Sumar los 2 meses anteriores para determinar los nuevos usuarios
#
# -Guardar los registros tanto de nuevos usuarios como de viejos usuarios
#
# Requerimientos NO Funcionales:
#
# -Mostrar de forma gráfica las estadisticas de crecimiento de la plataforma
#
# -Mostrar las estadisticas de crecimiento de diferentes formas
#
# -Dejar facil acceso a las estadisticas de crecimiento de la plataforma
#
# -Agilizar la ejecución del programa

# %% [markdown]
# ## 3) Historias de usuario **[2 pts]**
# HU001: Como nuevo suscriptor quiero poder registrarme en la plataforma para ver mis series favoritas.
#     Criterio aceptación: Permitir crear un usuario dentro de la plataforma
#
# HU002: Como análistia de datos quiero poder ver el crecimiento en los suscriptores para conocer los nuevos usuarios que vendran en los meses siguientes.
#     Criterio aceptación: Permitir ver los nuevos usuarios/suscrptores obtenidos en los siguientes meses.
# HU003: Como programador quiero sumar los nuevos usuarios de los dos meses anteriores para determinar los nuevos suscriptores del mes siguiente.
#     Criterio aceptación: Utilizar la ecuación de recurrencia segun los casos bases para obtener los nuevos suscriptores del proximo mes.

# %% [markdown]
# ## 4) Diagramas de flujo **[5 pts]**
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 5) Análisis de complejidad **[15 pts]**
# Incluye:
# - Justificación
# Se utiliza el metodo de memoización para almacenar los casos bases T(0)= 0 y T(1)= 1 para luego aplicar la ecuación de recurrencia para de esta forma poder obtener los nuevos usuarios de los meses siguientes.
# - Función T[n]
#
#     T(n) = T(n-1) + T(n-2)
#
# -Mejor caso
#
#     El mejor caso es cuando n= 1
#
# ![image-2.png](attachment:image-2.png)
#
#
# -El peor caso
#
#     El peor caso es cuando n = n
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 6) Código funcional **[15 pts]**
# Incluye tu implementación completa.
#
# No pegues código incompleto; debe ser ejecutable.

# %%
def save(n):
    lista = {}
    if n == 0:
        return 0
    if n == 1:
        return 1
    if n in lista:
        return lista[n]
    lista[n] = save(n - 1) + save(n - 2)
    return lista[n]
def main():
    n = int(input("Ingrese el valor de n: "))
    mes = save(n)
    print(f"El resultado de save({n}) es: {mes}")
 
main()
# Out:
# El resultado de save(10) es: 55

# %% [markdown]
# ## 7) Tests aplicados **[15 pts]**

# %%
def save(n):
    lista = {}
    if n == 0:
        return 0
    if n == 1:
        return 1
    if n in lista:
        return lista[n]
    lista[n] = save(n - 1) + save(n - 2)
    return lista[n]
def main():
    n = 0, 1, 6, 
    for x in n:
        mes = save(x)
        print(f"El resultado de save({x}) es: {mes}")
 
main()
# Out:
# El resultado de save(0) es: 0
# El resultado de save(1) es: 1
# El resultado de save(6) es: 8
# El resultado de save(7) es: 13
